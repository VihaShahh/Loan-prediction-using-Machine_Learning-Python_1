# %% [markdown]
# <a href="https://colab.research.google.com/github/VihaShahh/Loan-prediction-using-Machine_Learning-Python_1/blob/main/Loan_prediction_using_Machine_Learning_and_Python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Loan-prediction using Machine_Learning & Python_1**

# %%
#Geers up
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df_train = pd.read_csv('/content/1000156374.csv')

# %%
df_train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
#missing data
total = df_train.isnull().sum().sort_values(ascending=False)
percent = (df_train.isnull().sum()/df_train.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                    Total   Percent
# Credit_History        50  0.081433
# Self_Employed         32  0.052117
# LoanAmount            22  0.035831
# Dependents            15  0.024430
# Loan_Amount_Term      14  0.022801
# Gender                13  0.021173
# Married                3  0.004886
# Loan_ID                0  0.000000
# Education              0  0.000000
# ApplicantIncome        0  0.000000
# CoapplicantIncome      0  0.000000
# Property_Area          0  0.000000
# Loan_Status            0  0.000000

# %%
df_train['Gender'] = df_train['Gender'].fillna(
                               df_train['Gender'].dropna().mode().values[0] )
df_train['Married'] = df_train['Married'].fillna(
                               df_train['Married'].dropna().mode().values[0] )
df_train['Dependents'] = df_train['Dependents'].fillna(
                               df_train['Dependents'].dropna().mode().values[0] )
df_train['Self_Employed'] = df_train['Self_Employed'].fillna(
                               df_train['Self_Employed'].dropna().mode().values[0] )
df_train['LoanAmount'] = df_train['LoanAmount'].fillna(
                               df_train['LoanAmount'].dropna().mean() )
df_train['Loan_Amount_Term'] = df_train['Loan_Amount_Term'].fillna(
                               df_train['Loan_Amount_Term'].dropna().mode().values[0] )
df_train['Credit_History'] = df_train['Credit_History'].fillna(
                               df_train['Credit_History'].dropna().mode().values[0] )

# %%
df_train['Credit_History'].value_counts()
# Out:
# 1.0    525
# 0.0     89
# Name: Credit_History, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

grid = sns.FacetGrid(df_train, row='Gender', col='Married', height=2.2, aspect=1.6)
grid.map(plt.hist, 'ApplicantIncome', alpha=.5, bins=10)
grid.add_legend()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

grid = sns.FacetGrid(df_train, row='Gender', col='Education', height=2.2, aspect=1.6)
grid.map(plt.hist, 'ApplicantIncome', alpha=.5, bins=10)
grid.add_legend()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

grid = sns.FacetGrid(df_train, row='Married', col='Education', height=2.2, aspect=1.6)
grid.map(plt.hist, 'ApplicantIncome', alpha=.5, bins=10)
grid.add_legend()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

grid = sns.FacetGrid(df_train, row='Self_Employed', col='Education', height=2.2, aspect=1.6)
grid.map(plt.hist, 'ApplicantIncome', alpha=.5, bins=10)
grid.add_legend()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

grid = sns.FacetGrid(df_train, row='Married', col='Dependents', height=3.2, aspect=1.6)
grid.map(plt.hist, 'ApplicantIncome', alpha=.5, bins=10)
grid.add_legend()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

grid = sns.FacetGrid(df_train, row='Married', col='Credit_History', height=3.2, aspect=1.6)
grid.map(plt.hist, 'ApplicantIncome', alpha=.5, bins=10)
grid.add_legend()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

grid = sns.FacetGrid(df_train, row='Credit_History', col='Property_Area', height=2.2, aspect=1.6)
grid.map(plt.hist, 'ApplicantIncome', alpha=.5, bins=10)
grid.add_legend()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

grid = sns.FacetGrid(df_train, row='Education', col='Credit_History', height=2.2, aspect=1.6)
grid.map(plt.hist, 'ApplicantIncome', alpha=.5, bins=10)
grid.add_legend()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

grid = sns.FacetGrid(df_train, row='Credit_History', col='Property_Area', height=2.2, aspect=1.6)
grid.map(plt.hist, 'LoanAmount', alpha=.5, bins=10)
grid.add_legend()

# %%
#histogram and normal probability plot
sns.distplot(df_train['ApplicantIncome'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_train['ApplicantIncome'], plot=plt)

# %%
flg, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (14,6))

sns.distplot(df_train['ApplicantIncome'], ax = axes[0]).set_title('ApplicantIncome Distribution')
axes[0].set_ylabel('ApplicantIncomee Count')

sns.distplot(df_train['CoapplicantIncome'], color = "r", ax = axes[1]).set_title('CoapplicantIncome Distribution')
axes[1].set_ylabel('CoapplicantIncome Count')

sns.distplot(df_train['LoanAmount'],color = "g", ax = axes[2]).set_title('LoanAmount Distribution')
axes[2].set_ylabel('LoanAmount Count')

plt.tight_layout()
plt.show()
plt.gcf().clear()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.FacetGrid(df_train, hue="Gender", height=6) \
   .map(sns.kdeplot, "ApplicantIncome") \
   .add_legend()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.FacetGrid(df_train, hue="Married", height=6) \
   .map(sns.kdeplot, "ApplicantIncome") \
   .add_legend()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.FacetGrid(df_train, hue="Married", height=6) \
   .map(sns.kdeplot, "ApplicantIncome") \
   .add_legend()

# %%
df_train.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
var_name = "CoapplicantIncome"
plt.figure(figsize=(12,6))
sns.regplot(x=var_name, y='ApplicantIncome', data=df_train, scatter_kws={'alpha':0.5, 's':30})
plt.xlabel(var_name, fontsize=12)
plt.ylabel('ApplicantIncome', fontsize=12)
plt.title("Distribution of y variable with "+var_name, fontsize=15)
plt.show()

# %%
var_name = "LoanAmount"
plt.figure(figsize=(12,6))
sns.regplot(x=var_name, y='ApplicantIncome', data=df_train, scatter_kws={'alpha':0.5, 's':30})
plt.xlabel(var_name, fontsize=12)
plt.ylabel('ApplicantIncome', fontsize=12)
plt.title("Distribution of y variable with "+var_name, fontsize=15)
plt.show()

# %%
#correlation matrix
corrmat = df_train.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
import matplotlib.pyplot as plt

# Check the first few rows of the DataFrame
print(df_train.head())

# Create subplots
fig, axes = plt.subplots(ncols=3, figsize=(12, 6))

# Plot countplots for each categorical variable
df_train["Gender"].value_counts().plot(kind="bar", ax=axes[0], rot=0)
axes[0].set_title("Gender")

df_train["Married"].value_counts().plot(kind="bar", ax=axes[1], rot=0)
axes[1].set_title("Married")

df_train["Dependents"].value_counts().plot(kind="bar", ax=axes[2], rot=0)
axes[2].set_title("Dependents")

# Adjust layout and display the plot
plt.tight_layout()
plt.show()
plt.gcf().clear()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
print(df_train["Education"].unique())
# Out:
# ['Graduate' 'Not Graduate']

# %%
df_train["Education"] = df_train["Education"].astype(str)

# %%
print(df_train["Self_Employed"].dtype)
# Out:
# object

# %%
df_train["Self_Employed"].value_counts().plot(kind="bar", ax=axes[1], rot=0)
axes[1].set_title("Self Employed")
# Out:
# Text(0.5, 1.0, 'Self Employed')

# %%
print(df_train.describe())
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  146.412162        342.410423
# std        6109.041673        2926.248369   84.037468         64.428629
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3812.500000        1188.500000  129.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      614.000000
# mean         0.855049
# std          0.352339
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df_train.shape
# Out:
# (614, 13)

# %%
df_train.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df_train[['Gender', 'ApplicantIncome']].groupby(['Gender'],
                                               as_index = False).mean().sort_values(by = 'Gender', ascending = False)
# Out:
#    Gender  ApplicantIncome
# 1    Male      5573.017928
# 0  Female      4643.473214
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['ApplicantIncome'].plot(kind='hist', bins=20, title='ApplicantIncome')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2['ApplicantIncome'].plot(kind='line', figsize=(8, 4), title='ApplicantIncome')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_3['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_3, x='ApplicantIncome', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df_train[['Married', 'ApplicantIncome']].groupby(['Married'],
                                               as_index = False).mean().sort_values(by = 'Married', ascending = False)
# Out:
#   Married  ApplicantIncome
# 1     Yes      5633.496259
# 0      No      4970.384977
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5['ApplicantIncome'].plot(kind='hist', bins=20, title='ApplicantIncome')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('Married').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='index', y='ApplicantIncome', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['ApplicantIncome'].plot(kind='line', figsize=(8, 4), title='ApplicantIncome')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_10['Married'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_10, x='index', y='Married', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_11['Married'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_11, x='ApplicantIncome', y='Married', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df_train[['Dependents', 'ApplicantIncome']].groupby(['Dependents'],
                                               as_index = False).mean().sort_values(by = 'Dependents', ascending = False)
# Out:
#   Dependents  ApplicantIncome
# 3         3+      8581.215686
# 2          2      4926.782178
# 1          1      5962.274510
# 0          0      4928.680556
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['ApplicantIncome'].plot(kind='hist', bins=20, title='ApplicantIncome')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_13.groupby('Dependents').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_14['ApplicantIncome'].plot(kind='line', figsize=(8, 4), title='ApplicantIncome')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_15['Dependents'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_15, x='ApplicantIncome', y='Dependents', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df_train[['Education', 'ApplicantIncome']].groupby(['Education'],
                                               as_index = False).mean().sort_values(by = 'Education', ascending = False)
# Out:
#       Education  ApplicantIncome
# 1  Not Graduate      3777.283582
# 0      Graduate      5857.433333

# %%
df_train[['Self_Employed', 'ApplicantIncome']].groupby(['Self_Employed'],
                                               as_index = False).mean().sort_values(by = 'Self_Employed', ascending = False)
# Out:
#   Self_Employed  ApplicantIncome
# 1           Yes      7380.817073
# 0            No      5098.678571

# %%
df_train[['Gender', 'Married', 'ApplicantIncome']].groupby(['Gender', 'Married'],
                                               as_index = False).mean().sort_values(by = 'Gender',
                                                                                          ascending = False)
# Out:
#    Gender Married  ApplicantIncome
# 2    Male      No      5251.045113
# 3    Male     Yes      5689.067751
# 0  Female      No      4503.787500
# 1  Female     Yes      4992.687500

# %%
df_train.groupby(['Gender']).size()[0]/(df_train.groupby(['Gender']).size()[0] +
                                        df_train.groupby(['Gender']).size()[1])
# Out:
# 0.18241042345276873
